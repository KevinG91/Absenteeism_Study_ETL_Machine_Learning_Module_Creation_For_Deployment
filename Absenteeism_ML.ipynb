# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
import pickle

# %%
data_preprocessed = pd.read_csv('Absenteeism_preprocessed.csv')
data_preprocessed.head()
# Out:
#    Reason 1  Reason 2  Reason 3  Reason 4  Day of the Week  Month  \
# 0         0         0         0         1                2      7
# 1         0         0         0         0                2      7
# 2         0         0         0         1                3      7
# 3         1         0         0         0                4      7
# 4         0         0         0         1                4      7
#
#    Transportation Expense  Distance to Work  Age  Daily Work Load Average  \
# 0                     289                36   33                  239.554
# 1                     118                13   50                  239.554
# 2                     179                51   38                  239.554
# 3                     279                 5   39                  239.554
# 4                     289                36   33                  239.554
#
#    Normal Weight  Overweight  Obese  Education  Children  Pets  \
# 0              0           0      1          0         1     1
# 1              0           0      1          0         1     0
# 2              0           0      1          0         0     0
# 3              1           0      0          0         1     0
# 4              0           0      1          0         1     1
#
#    Excessive Absenteeism
# 0                      1
# 1                      0
# 2                      0
# 3                      1
# 4                      0

# %% [markdown]
# splitting the inputs

# %%
unscaled_inputs = data_preprocessed.iloc[:,:-1]
unscaled_inputs
# Out:
#      Reason 1  Reason 2  Reason 3  Reason 4  Day of the Week  Month  \
# 0           0         0         0         1                2      7
# 1           0         0         0         0                2      7
# 2           0         0         0         1                3      7
# 3           1         0         0         0                4      7
# 4           0         0         0         1                4      7
# ..        ...       ...       ...       ...              ...    ...
# 695         1         0         0         0                3      5
# 696         1         0         0         0                3      5
# 697         1         0         0         0                4      5
# 698         0         0         0         1                4      5
# 699         0         0         0         1                4      5
#
#      Transportation Expense  Distance to Work  Age  Daily Work Load Average  \
# 0                       289                36   33                  239.554
# 1                       118                13   50                  239.554
# 2                       179                51   38                  239.554
# 3                       279                 5   39                  239.554
# 4                       289                36   33                  239.554
# ..                      ...               ...  ...                      ...
# 695                     179                22   40                  237.656
# 696                     225                26   28                  237.656
# 697                     330                16   28                  237.656
# 698                     235                16   32                  237.656
# 699                     291                31   40                  237.656
#
#      Normal Weight  Overweight  Obese  Education  Children  Pets
# 0                0           0      1          0         1     1
# 1                0           0      1          0         1     0
# 2                0           0      1          0         0     0
# 3                1           0      0          0         1     0
# 4                0           0      1          0         1     1
# ..             ...         ...    ...        ...       ...   ...
# 695              1           0      0          1         1     0
# 696              1           0      0          0         1     1
# 697              0           1      0          1         0     0
# 698              0           1      0          1         0     0
# 699              0           1      0          0         1     1
#
# [700 rows x 16 columns]

# %%
targets = list(data_preprocessed.iloc[:,-1])

# %% [markdown]
# with standardscaler we can standardize the values

# %%
scaler = StandardScaler()

# %%
scaler.fit(unscaled_inputs)
# Out:
# StandardScaler()

# %%
scaled_inputs = scaler.transform(unscaled_inputs)

# %%
scaled_inputs
# Out:
# array([[-0.57735027, -0.09298136, -0.31448545, ..., -0.44798003,
#          0.82870199,  1.29691647],
#        [-0.57735027, -0.09298136, -0.31448545, ..., -0.44798003,
#          0.82870199, -0.77105968],
#        [-0.57735027, -0.09298136, -0.31448545, ..., -0.44798003,
#         -1.20670641, -0.77105968],
#        ...,
#        [ 1.73205081, -0.09298136, -0.31448545, ...,  2.23224237,
#         -1.20670641, -0.77105968],
#        [-0.57735027, -0.09298136, -0.31448545, ...,  2.23224237,
#         -1.20670641, -0.77105968],
#        [-0.57735027, -0.09298136, -0.31448545, ..., -0.44798003,
#          0.82870199,  1.29691647]])

# %%
scaled_inputs.shape
# Out:
# (700, 16)

# %% [markdown]
# we classified most of the variables in the dataset so i'm going to be using a logistic regression for this case in particular as it is the best fit for categorical variables

# %%
x_train, x_test, y_train, y_test = train_test_split(scaled_inputs, targets, train_size= 0.8, random_state=20)

# %%
logreg = LogisticRegression()

# %%
logreg.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
logreg.score(x_train, y_train)
# Out:
# 0.7785714285714286

# %% [markdown]
# not great, not terrible, we should look at the variables

# %%
names = unscaled_inputs.columns.values
names
# Out:
# array(['Reason 1', 'Reason 2', 'Reason 3', 'Reason 4', 'Day of the Week',
#        'Month', 'Transportation Expense', 'Distance to Work', 'Age',
#        'Daily Work Load Average', 'Normal Weight', 'Overweight', 'Obese',
#        'Education', 'Children', 'Pets'], dtype=object)

# %% [markdown]
# we can get the coefficient, or weights, of the variables to look at the data

# %%
variables_table = pd.DataFrame(columns=['Name'], data=names)
variables_table['Coefficient'] = np.transpose(logreg.coef_)
variables_table
# Out:
#                        Name  Coefficient
# 0                  Reason 1     2.154799
# 1                  Reason 2     0.350154
# 2                  Reason 3     1.612093
# 3                  Reason 4     1.414509
# 4           Day of the Week    -0.019982
# 5                     Month     0.189042
# 6    Transportation Expense     0.867042
# 7          Distance to Work     0.023248
# 8                       Age    -0.134078
# 9   Daily Work Load Average    -0.036191
# 10            Normal Weight    -0.216063
# 11               Overweight     0.170191
# 12                    Obese     0.052885
# 13                Education    -0.249898
# 14                 Children     0.422766
# 15                     Pets    -0.723806

# %% [markdown]
# we are still missing the intercept, or bias

# %%
variables_table.index = variables_table.index+1
variables_table
# Out:
#                        Name  Coefficient
# 1                  Reason 1     2.154799
# 2                  Reason 2     0.350154
# 3                  Reason 3     1.612093
# 4                  Reason 4     1.414509
# 5           Day of the Week    -0.019982
# 6                     Month     0.189042
# 7    Transportation Expense     0.867042
# 8          Distance to Work     0.023248
# 9                       Age    -0.134078
# 10  Daily Work Load Average    -0.036191
# 11            Normal Weight    -0.216063
# 12               Overweight     0.170191
# 13                    Obese     0.052885
# 14                Education    -0.249898
# 15                 Children     0.422766
# 16                     Pets    -0.723806

# %% [markdown]
# we can add it now, but it will be at the bottom

# %%
variables_table.loc[0] = ['Intercept', logreg.intercept_[0]]
variables_table
# Out:
#                        Name  Coefficient
# 1                  Reason 1     2.154799
# 2                  Reason 2     0.350154
# 3                  Reason 3     1.612093
# 4                  Reason 4     1.414509
# 5           Day of the Week    -0.019982
# 6                     Month     0.189042
# 7    Transportation Expense     0.867042
# 8          Distance to Work     0.023248
# 9                       Age    -0.134078
# 10  Daily Work Load Average    -0.036191
# 11            Normal Weight    -0.216063
# 12               Overweight     0.170191
# 13                    Obese     0.052885
# 14                Education    -0.249898
# 15                 Children     0.422766
# 16                     Pets    -0.723806
# 0                 Intercept    -0.223554

# %% [markdown]
# so we sort the table

# %%
variables_table = variables_table.sort_index()
variables_table
# Out:
#                        Name  Coefficient
# 0                 Intercept    -0.223554
# 1                  Reason 1     2.154799
# 2                  Reason 2     0.350154
# 3                  Reason 3     1.612093
# 4                  Reason 4     1.414509
# 5           Day of the Week    -0.019982
# 6                     Month     0.189042
# 7    Transportation Expense     0.867042
# 8          Distance to Work     0.023248
# 9                       Age    -0.134078
# 10  Daily Work Load Average    -0.036191
# 11            Normal Weight    -0.216063
# 12               Overweight     0.170191
# 13                    Obese     0.052885
# 14                Education    -0.249898
# 15                 Children     0.422766
# 16                     Pets    -0.723806

# %%
variables_table['Odds_Ratio'] = np.exp(variables_table.Coefficient)
variables_table.sort_values('Odds_Ratio', ascending=False)
# Out:
#                        Name  Coefficient  Odds_Ratio
# 1                  Reason 1     2.154799    8.626153
# 3                  Reason 3     1.612093    5.013292
# 4                  Reason 4     1.414509    4.114465
# 7    Transportation Expense     0.867042    2.379860
# 15                 Children     0.422766    1.526178
# 2                  Reason 2     0.350154    1.419286
# 6                     Month     0.189042    1.208091
# 12               Overweight     0.170191    1.185532
# 13                    Obese     0.052885    1.054309
# 8          Distance to Work     0.023248    1.023520
# 5           Day of the Week    -0.019982    0.980216
# 10  Daily Work Load Average    -0.036191    0.964456
# 9                       Age    -0.134078    0.874522
# 11            Normal Weight    -0.216063    0.805685
# 0                 Intercept    -0.223554    0.799672
# 14                Education    -0.249898    0.778880
# 16                     Pets    -0.723806    0.484903

# %% [markdown]
# Here we can see which variables are more or less relevant, a variables is not important if:
# * the coefficient is around 0
# * the odds ratio is around 1
# ###### A weight close to 0 will null the variable and an odds ratio close to 1 means it will remain almost the same

# %%
irrelevant_variables = variables_table.loc[(variables_table['Coefficient'] > -0.05) & (variables_table['Coefficient']< 0.05)]
irrelevant_variables
# Out:
#                        Name  Coefficient  Odds_Ratio
# 5           Day of the Week    -0.019982    0.980216
# 8          Distance to Work     0.023248    1.023520
# 10  Daily Work Load Average    -0.036191    0.964456

# %% [markdown]
# that's interesting, woulda thought distance to work and work load would way more considering work load directly affects the employee mentally

# %% [markdown]
# knowing this it would be safe to drop this columns and the accuracy of the model would remain the same

# %%
irrelevant_columns = list(irrelevant_variables.Name.values)
irrelevant_columns
# Out:
# ['Day of the Week', 'Distance to Work', 'Daily Work Load Average']

# %% [markdown]
# let's drop em

# %%
unscaled_inputs = unscaled_inputs.drop(columns=irrelevant_columns, axis=1)
unscaled_inputs
# Out:
#      Reason 1  Reason 2  Reason 3  Reason 4  Month  Transportation Expense  \
# 0           0         0         0         1      7                     289
# 1           0         0         0         0      7                     118
# 2           0         0         0         1      7                     179
# 3           1         0         0         0      7                     279
# 4           0         0         0         1      7                     289
# ..        ...       ...       ...       ...    ...                     ...
# 695         1         0         0         0      5                     179
# 696         1         0         0         0      5                     225
# 697         1         0         0         0      5                     330
# 698         0         0         0         1      5                     235
# 699         0         0         0         1      5                     291
#
#      Age  Normal Weight  Overweight  Obese  Education  Children  Pets
# 0     33              0           0      1          0         1     1
# 1     50              0           0      1          0         1     0
# 2     38              0           0      1          0         0     0
# 3     39              1           0      0          0         1     0
# 4     33              0           0      1          0         1     1
# ..   ...            ...         ...    ...        ...       ...   ...
# 695   40              1           0      0          1         1     0
# 696   28              1           0      0          0         1     1
# 697   28              0           1      0          1         0     0
# 698   32              0           1      0          1         0     0
# 699   40              0           1      0          0         1     1
#
# [700 rows x 13 columns]

# %% [markdown]
# for clarity's sake i will go through the scaling process again

# %%
scaler = StandardScaler()
scaler.fit(unscaled_inputs)
scaled_inputs = scaler.transform(unscaled_inputs)

# %%
logreg = LogisticRegression()
x_train, x_test, y_train, y_test = train_test_split(scaled_inputs, targets, train_size= 0.8, random_state=20)
logreg.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
logreg.score(x_train, y_train)
# Out:
# 0.7821428571428571

# %% [markdown]
# indeed it is a tiny bit more accurate, it's good to remove redundant variables

# %% [markdown]
# Let's test the model with unknown variables

# %%
logreg.score(x_test, y_test)
# Out:
# 0.7142857142857143

# %%
(logreg.score(x_train, y_train) - logreg.score(x_test, y_test)) * 100
# Out:
# 6.785714285714284

# %% [markdown]
# less than a 7% difference, it's ok, don't think we overfitted

# %% [markdown]
# we can get the probabiliy of each variable to land true in excess absenteeism. The first value is for 0 and the second 1 so we want to keep the ones in the second position

# %%
probabilities = logreg.predict_proba(x_test)
probabilities
# Out:
# array([[0.70627239, 0.29372761],
#        [0.49674211, 0.50325789],
#        [0.35617621, 0.64382379],
#        [0.78897163, 0.21102837],
#        [0.08749558, 0.91250442],
#        [0.31894411, 0.68105589],
#        [0.31312296, 0.68687704],
#        [0.17692731, 0.82307269],
#        [0.863386  , 0.136614  ],
#        [0.74989324, 0.25010676],
#        [0.23040629, 0.76959371],
#        [0.0784381 , 0.9215619 ],
#        [0.05497183, 0.94502817],
#        [0.84128329, 0.15871671],
#        [0.37917923, 0.62082077],
#        [0.37760783, 0.62239217],
#        [0.2828943 , 0.7171057 ],
#        [0.27183674, 0.72816326],
#        [0.57018949, 0.42981051],
#        [0.05560405, 0.94439595],
#        [0.78447967, 0.21552033],
#        [0.78897163, 0.21102837],
#        [0.34686606, 0.65313394],
#        [0.34686606, 0.65313394],
#        [0.25645135, 0.74354865],
#        [0.8274746 , 0.1725254 ],
#        [0.38886884, 0.61113116],
#        [0.88851845, 0.11148155],
#        [0.13408319, 0.86591681],
#        [0.78897163, 0.21102837],
#        [0.55173   , 0.44827   ],
#        [0.41483544, 0.58516456],
#        [0.29546744, 0.70453256],
#        [0.21142355, 0.78857645],
#        [0.78897163, 0.21102837],
#        [0.61351797, 0.38648203],
#        [0.8567468 , 0.1432532 ],
#        [0.1050821 , 0.8949179 ],
#        [0.76947887, 0.23052113],
#        [0.43358519, 0.56641481],
#        [0.79801138, 0.20198862],
#        [0.60819224, 0.39180776],
#        [0.84266356, 0.15733644],
#        [0.93302482, 0.06697518],
#        [0.29692037, 0.70307963],
#        [0.29801585, 0.70198415],
#        [0.16980257, 0.83019743],
#        [0.70627239, 0.29372761],
#        [0.74820227, 0.25179773],
#        [0.80675874, 0.19324126],
#        [0.45829933, 0.54170067],
#        [0.88240638, 0.11759362],
#        [0.31894411, 0.68105589],
#        [0.68092044, 0.31907956],
#        [0.11003359, 0.88996641],
#        [0.46919428, 0.53080572],
#        [0.02614377, 0.97385623],
#        [0.63309391, 0.36690609],
#        [0.91831695, 0.08168305],
#        [0.91408164, 0.08591836],
#        [0.21651652, 0.78348348],
#        [0.3310467 , 0.6689533 ],
#        [0.53974023, 0.46025977],
#        [0.20745025, 0.79254975],
#        [0.82745198, 0.17254802],
#        [0.72863251, 0.27136749],
#        [0.98918084, 0.01081916],
#        [0.8567468 , 0.1432532 ],
#        [0.16061904, 0.83938096],
#        [0.80955368, 0.19044632],
#        [0.8567468 , 0.1432532 ],
#        [0.9003015 , 0.0996985 ],
#        [0.06154077, 0.93845923],
#        [0.71697433, 0.28302567],
#        [0.53272364, 0.46727636],
#        [0.78897163, 0.21102837],
#        [0.15449043, 0.84550957],
#        [0.38586376, 0.61413624],
#        [0.19314408, 0.80685592],
#        [0.47412522, 0.52587478],
#        [0.8352095 , 0.1647905 ],
#        [0.98571305, 0.01428695],
#        [0.63309391, 0.36690609],
#        [0.31315704, 0.68684296],
#        [0.55239588, 0.44760412],
#        [0.90857772, 0.09142228],
#        [0.27302607, 0.72697393],
#        [0.34686606, 0.65313394],
#        [0.94444074, 0.05555926],
#        [0.41483544, 0.58516456],
#        [0.86351327, 0.13648673],
#        [0.82561603, 0.17438397],
#        [0.77963904, 0.22036096],
#        [0.72863251, 0.27136749],
#        [0.74989324, 0.25010676],
#        [0.09040162, 0.90959838],
#        [0.69469771, 0.30530229],
#        [0.11625148, 0.88374852],
#        [0.71576003, 0.28423997],
#        [0.81961475, 0.18038525],
#        [0.50518345, 0.49481655],
#        [0.41483544, 0.58516456],
#        [0.23978836, 0.76021164],
#        [0.17336677, 0.82663323],
#        [0.72803508, 0.27196492],
#        [0.69405695, 0.30594305],
#        [0.71758663, 0.28241337],
#        [0.09040162, 0.90959838],
#        [0.13398804, 0.86601196],
#        [0.83341748, 0.16658252],
#        [0.98718658, 0.01281342],
#        [0.14420892, 0.85579108],
#        [0.26539407, 0.73460593],
#        [0.59222817, 0.40777183],
#        [0.62651571, 0.37348429],
#        [0.4883662 , 0.5116338 ],
#        [0.07777048, 0.92222952],
#        [0.30643877, 0.69356123],
#        [0.35912256, 0.64087744],
#        [0.77500507, 0.22499493],
#        [0.73940325, 0.26059675],
#        [0.87103883, 0.12896117],
#        [0.06067506, 0.93932494],
#        [0.60819224, 0.39180776],
#        [0.78897163, 0.21102837],
#        [0.76336984, 0.23663016],
#        [0.79801138, 0.20198862],
#        [0.88040383, 0.11959617],
#        [0.23147199, 0.76852801],
#        [0.78447967, 0.21552033],
#        [0.42008801, 0.57991199],
#        [0.79801138, 0.20198862],
#        [0.69469771, 0.30530229],
#        [0.76336984, 0.23663016],
#        [0.58049799, 0.41950201],
#        [0.62651571, 0.37348429],
#        [0.27183674, 0.72816326],
#        [0.80090162, 0.19909838],
#        [0.71576003, 0.28423997],
#        [0.71697433, 0.28302567]])

# %%
probabilities = probabilities[:,1]
probabilities
# Out:
# array([0.29372761, 0.50325789, 0.64382379, 0.21102837, 0.91250442,
#        0.68105589, 0.68687704, 0.82307269, 0.136614  , 0.25010676,
#        0.76959371, 0.9215619 , 0.94502817, 0.15871671, 0.62082077,
#        0.62239217, 0.7171057 , 0.72816326, 0.42981051, 0.94439595,
#        0.21552033, 0.21102837, 0.65313394, 0.65313394, 0.74354865,
#        0.1725254 , 0.61113116, 0.11148155, 0.86591681, 0.21102837,
#        0.44827   , 0.58516456, 0.70453256, 0.78857645, 0.21102837,
#        0.38648203, 0.1432532 , 0.8949179 , 0.23052113, 0.56641481,
#        0.20198862, 0.39180776, 0.15733644, 0.06697518, 0.70307963,
#        0.70198415, 0.83019743, 0.29372761, 0.25179773, 0.19324126,
#        0.54170067, 0.11759362, 0.68105589, 0.31907956, 0.88996641,
#        0.53080572, 0.97385623, 0.36690609, 0.08168305, 0.08591836,
#        0.78348348, 0.6689533 , 0.46025977, 0.79254975, 0.17254802,
#        0.27136749, 0.01081916, 0.1432532 , 0.83938096, 0.19044632,
#        0.1432532 , 0.0996985 , 0.93845923, 0.28302567, 0.46727636,
#        0.21102837, 0.84550957, 0.61413624, 0.80685592, 0.52587478,
#        0.1647905 , 0.01428695, 0.36690609, 0.68684296, 0.44760412,
#        0.09142228, 0.72697393, 0.65313394, 0.05555926, 0.58516456,
#        0.13648673, 0.17438397, 0.22036096, 0.27136749, 0.25010676,
#        0.90959838, 0.30530229, 0.88374852, 0.28423997, 0.18038525,
#        0.49481655, 0.58516456, 0.76021164, 0.82663323, 0.27196492,
#        0.30594305, 0.28241337, 0.90959838, 0.86601196, 0.16658252,
#        0.01281342, 0.85579108, 0.73460593, 0.40777183, 0.37348429,
#        0.5116338 , 0.92222952, 0.69356123, 0.64087744, 0.22499493,
#        0.26059675, 0.12896117, 0.93932494, 0.39180776, 0.21102837,
#        0.23663016, 0.20198862, 0.11959617, 0.76852801, 0.21552033,
#        0.57991199, 0.20198862, 0.30530229, 0.23663016, 0.41950201,
#        0.37348429, 0.72816326, 0.19909838, 0.28423997, 0.28302567])

# %% [markdown]
# let's get the %

# %%
probabilities = [round(number*100,2) for number in probabilities]
probabilities
# Out:
# [29.37,
#  50.33,
#  64.38,
#  21.1,
#  91.25,
#  68.11,
#  68.69,
#  82.31,
#  13.66,
#  25.01,
#  76.96,
#  92.16,
#  94.5,
#  15.87,
#  62.08,
#  62.24,
#  71.71,
#  72.82,
#  42.98,
#  94.44,
#  21.55,
#  21.1,
#  65.31,
#  65.31,
#  74.35,
#  17.25,
#  61.11,
#  11.15,
#  86.59,
#  21.1,
#  44.83,
#  58.52,
#  70.45,
#  78.86,
#  21.1,
#  38.65,
#  14.33,
#  89.49,
#  23.05,
#  56.64,
#  20.2,
#  39.18,
#  15.73,
#  6.7,
#  70.31,
#  70.2,
#  83.02,
#  29.37,
#  25.18,
#  19.32,
#  54.17,
#  11.76,
#  68.11,
#  31.91,
#  89.0,
#  53.08,
#  97.39,
#  36.69,
#  8.17,
#  8.59,
#  78.35,
#  66.9,
#  46.03,
#  79.25,
#  17.25,
#  27.14,
#  1.08,
#  14.33,
#  83.94,
#  19.04,
#  14.33,
#  9.97,
#  93.85,
#  28.3,
#  46.73,
#  21.1,
#  84.55,
#  61.41,
#  80.69,
#  52.59,
#  16.48,
#  1.43,
#  36.69,
#  68.68,
#  44.76,
#  9.14,
#  72.7,
#  65.31,
#  5.56,
#  58.52,
#  13.65,
#  17.44,
#  22.04,
#  27.14,
#  25.01,
#  90.96,
#  30.53,
#  88.37,
#  28.42,
#  18.04,
#  49.48,
#  58.52,
#  76.02,
#  82.66,
#  27.2,
#  30.59,
#  28.24,
#  90.96,
#  86.6,
#  16.66,
#  1.28,
#  85.58,
#  73.46,
#  40.78,
#  37.35,
#  51.16,
#  92.22,
#  69.36,
#  64.09,
#  22.5,
#  26.06,
#  12.9,
#  93.93,
#  39.18,
#  21.1,
#  23.66,
#  20.2,
#  11.96,
#  76.85,
#  21.55,
#  57.99,
#  20.2,
#  30.53,
#  23.66,
#  41.95,
#  37.35,
#  72.82,
#  19.91,
#  28.42,
#  28.3]

# %%
len(probabilities)
# Out:
# 140

# %% [markdown]
# to make it fancy we can add those % to each register that was predicted

# %%
raw_csv = pd.read_csv('Absenteeism_data.csv')

# %%
employee_percentage = raw_csv.iloc[560:,:]
employee_percentage.insert(1,'Excess Absenteeism probability', probabilities)
employee_percentage = employee_percentage.iloc[:,:2]
employee_percentage.sort_values('Excess Absenteeism probability', ascending=False)
# Out:
#      ID  Excess Absenteeism probability
# 616   3                           97.39
# 572  17                           94.50
# 579  14                           94.44
# 682  26                           93.93
# 632   3                           93.85
# ..   ..                             ...
# 603  12                            6.70
# 648  14                            5.56
# 641   3                            1.43
# 670  14                            1.28
# 626  28                            1.08
#
# [140 rows x 2 columns]

# %% [markdown]
# And that's pretty much it for predictions

# %% [markdown]
# Let's save the model

# %%
with open('model', 'wb') as f:
    pickle.dump(logreg, f)

# %% [markdown]
# and the scaler too

# %%
with open('scaler', 'wb') as f:
    pickle.dump(scaler, f)

# %% [markdown]
# next we should make a module that processes data with the same format so we can test the model and the scaler
