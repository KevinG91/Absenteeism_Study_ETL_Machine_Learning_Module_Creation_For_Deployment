# %% [markdown]
# We need to load the module first, the .py script we wrote

# %%
from Absenteeism_classes_module import *

# %% [markdown]
# next we load the model and scaler files

# %%
model = AbsenteeismModel('model', 'scaler')

# %% [markdown]
# if we did everything right and properly pasted the jupyter notebook it should clean the data

# %%
model.ETL_process('Absenteeism_new_data.csv')

# %% [markdown]
# nice

# %% [markdown]
# let's check the predictions now

# %%
model.predicted_outputs()
# Out:
#     Reason 1  Reason 2  Reason 3  Reason 4  Month  Transportation Expense  \
# 0          0       0.0         0         1      6                     179
# 1          1       0.0         0         0      6                     361
# 2          0       0.0         0         1      6                     155
# 3          0       0.0         0         1      6                     179
# 4          1       0.0         0         0      6                     155
# 5          1       0.0         0         0      6                     225
# 6          1       0.0         0         0      6                     118
# 7          0       0.0         0         1      6                     179
# 8          0       0.0         0         1      6                     118
# 9          1       0.0         0         0      6                     118
# 10         0       0.0         0         1      6                     378
# 11         0       0.0         1         0      6                     118
# ...

# %% [markdown]
# perfect, we can now save the new predictions to a csv file in case we want to analyse the results

# %%
model.predicted_outputs().to_csv('Absenteeism_new_data_predictions.csv', index = False)

# %% [markdown]
# And that's it for this exercise
